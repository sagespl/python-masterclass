# %% [markdown]
# # Pandas - DataFrame - przekształcenia - lekcja

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(0)

df = pd.DataFrame(
    columns = ['Morning', 'Noon', 'Evening', 'Midnight'],
    index = pd.date_range('1999-12-30', periods=7),
    data = np.random.randn(7, 4))

df
# Out:
#              Morning      Noon   Evening  Midnight
# 1999-12-30  1.764052  0.400157  0.978738  2.240893
# 1999-12-31  1.867558 -0.977278  0.950088 -0.151357
# 2000-01-01 -0.103219  0.410599  0.144044  1.454274
# 2000-01-02  0.761038  0.121675  0.443863  0.333674
# 2000-01-03  1.494079 -0.205158  0.313068 -0.854096
# 2000-01-04 -2.552990  0.653619  0.864436 -0.742165
# 2000-01-05  2.269755 -1.454366  0.045759 -0.187184

# %% [markdown]
# ## Wartości puste
#
# - Wybieranie wartości pustych:
#
#     - Any
#     - All
#     - Czy null
#     - Czy puste
#
# - Wypełnianie
#
#     - Wypełnianie skalarne
#     - Wypełnianie słownikowe
#     - Wypełnianie w przód
#     - Wypełnianie w tył
#     - Interpolacja
#
# - Usuwanie:
#
#     - Usuwanie pustych wierszy (any, all)
#     - Usuwanie pustych kolumn (any, all)

# %%
df.any()
# Out:
# Morning     True
# Noon        True
# Evening     True
# Midnight    True
# dtype: bool

# %%
df.all()
# Out:
# Morning     True
# Noon        True
# Evening     True
# Midnight    True
# dtype: bool

# %%
df[df > 0.5] = pd.NA

# %%
df
# Out:
#              Morning      Noon   Evening  Midnight
# 1999-12-30       NaN  0.400157       NaN       NaN
# 1999-12-31       NaN -0.977278       NaN -0.151357
# 2000-01-01 -0.103219  0.410599  0.144044       NaN
# 2000-01-02       NaN  0.121675  0.443863  0.333674
# 2000-01-03       NaN -0.205158  0.313068 -0.854096
# 2000-01-04 -2.552990       NaN       NaN -0.742165
# 2000-01-05       NaN -1.454366  0.045759 -0.187184

# %%
df.ffill()
# Out:
#              Morning      Noon   Evening  Midnight
# 1999-12-30       NaN  0.400157       NaN       NaN
# 1999-12-31       NaN -0.977278       NaN -0.151357
# 2000-01-01 -0.103219  0.410599  0.144044 -0.151357
# 2000-01-02 -0.103219  0.121675  0.443863  0.333674
# 2000-01-03 -0.103219 -0.205158  0.313068 -0.854096
# 2000-01-04 -2.552990 -0.205158  0.313068 -0.742165
# 2000-01-05 -2.552990 -1.454366  0.045759 -0.187184

# %%
df.bfill()
# Out:
#              Morning      Noon   Evening  Midnight
# 1999-12-30 -0.103219  0.400157  0.144044 -0.151357
# 1999-12-31 -0.103219 -0.977278  0.144044 -0.151357
# 2000-01-01 -0.103219  0.410599  0.144044  0.333674
# 2000-01-02 -2.552990  0.121675  0.443863  0.333674
# 2000-01-03 -2.552990 -0.205158  0.313068 -0.854096
# 2000-01-04 -2.552990 -1.454366  0.045759 -0.742165
# 2000-01-05       NaN -1.454366  0.045759 -0.187184

# %%
df.ffill().bfill()
# Out:
#              Morning      Noon   Evening  Midnight
# 1999-12-30 -0.103219  0.400157  0.144044 -0.151357
# 1999-12-31 -0.103219 -0.977278  0.144044 -0.151357
# 2000-01-01 -0.103219  0.410599  0.144044 -0.151357
# 2000-01-02 -0.103219  0.121675  0.443863  0.333674
# 2000-01-03 -0.103219 -0.205158  0.313068 -0.854096
# 2000-01-04 -2.552990 -0.205158  0.313068 -0.742165
# 2000-01-05 -2.552990 -1.454366  0.045759 -0.187184

# %%
df.interpolate(method='polynomial', order=2, axis='columns')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-b3d1a06f5351> in <module>
# ----> 1 df.interpolate(method='polynomial', order=2, axis='columns')
#
# ~/.virtualenvs/python-w-analizie-danych/lib/python3.8/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6846             )
#    6847             if method not in methods and not is_numeric_or_datetime:
# -> 6848                 raise ValueError(
#    6849                     "Index column must be numeric or datetime type when "
#    6850                     f"using {method} method other than linear. "
#
# ValueError: Index column must be numeric or datetime type when using polynomial method other than linear. Try setting a numeric or datetime index column before interpolating.

# %%
df.interpolate?

# %%
df.isna()
# Out:
#             Morning   Noon  Evening  Midnight
# 1999-12-30     True  False     True      True
# 1999-12-31     True  False     True     False
# 2000-01-01    False  False    False      True
# 2000-01-02     True  False    False     False
# 2000-01-03     True  False    False     False
# 2000-01-04    False   True     True     False
# 2000-01-05     True  False    False     False

# %%
query = df['Noon'] > 0.5

df.loc[query, 'Noon'].isna()
# Out:
# Series([], Freq: D, Name: Noon, dtype: bool)

# %%
df
# Out:
#              Morning      Noon   Evening  Midnight
# 1999-12-30       NaN  0.400157       NaN       NaN
# 1999-12-31       NaN -0.977278       NaN -0.151357
# 2000-01-01 -0.103219  0.410599  0.144044       NaN
# 2000-01-02       NaN  0.121675  0.443863  0.333674
# 2000-01-03       NaN -0.205158  0.313068 -0.854096
# 2000-01-04 -2.552990       NaN       NaN -0.742165
# 2000-01-05       NaN -1.454366  0.045759 -0.187184

# %%
df.fillna(0)
# Out:
#              Morning      Noon   Evening  Midnight
# 1999-12-30  0.000000  0.400157  0.000000  0.000000
# 1999-12-31  0.000000 -0.977278  0.000000 -0.151357
# 2000-01-01 -0.103219  0.410599  0.144044  0.000000
# 2000-01-02  0.000000  0.121675  0.443863  0.333674
# 2000-01-03  0.000000 -0.205158  0.313068 -0.854096
# 2000-01-04 -2.552990  0.000000  0.000000 -0.742165
# 2000-01-05  0.000000 -1.454366  0.045759 -0.187184

# %%
df.isna()
# Out:
#             Morning  Noon  Evening  Midnight
# 1999-12-30      NaN   NaN      NaN       NaN
# 1999-12-31      NaN   NaN      NaN       NaN
# 2000-01-01      NaN   NaN      NaN       NaN
# 2000-01-02      NaN   NaN      NaN       NaN
# 2000-01-03      NaN   NaN      NaN       NaN
# 2000-01-04      NaN   NaN      NaN       NaN
# 2000-01-05      NaN   NaN      NaN       NaN

# %%
df.drop(columns=['Noon', 'Midnight'])
# Out:
#              Morning   Evening
# 1999-12-30       NaN       NaN
# 1999-12-31       NaN       NaN
# 2000-01-01 -0.103219  0.144044
# 2000-01-02       NaN  0.443863
# 2000-01-03       NaN  0.313068
# 2000-01-04 -2.552990       NaN
# 2000-01-05       NaN  0.045759

# %%
df.drop(index=[pd.Timestamp('1999-12-31'), pd.Timestamp('2000-01-03')])
# Out:
#              Morning      Noon   Evening  Midnight
# 1999-12-30       NaN  0.400157       NaN       NaN
# 2000-01-01 -0.103219  0.410599  0.144044       NaN
# 2000-01-02       NaN  0.121675  0.443863  0.333674
# 2000-01-04 -2.552990       NaN       NaN -0.742165
# 2000-01-05       NaN -1.454366  0.045759 -0.187184

# %%
rows = ['1999-12-31', '2000-01-03']

df.drop(index=map(pd.Timestamp, rows))
# Out:
#              Morning      Noon   Evening  Midnight
# 1999-12-30       NaN  0.400157       NaN       NaN
# 2000-01-01 -0.103219  0.410599  0.144044       NaN
# 2000-01-02       NaN  0.121675  0.443863  0.333674
# 2000-01-04 -2.552990       NaN       NaN -0.742165
# 2000-01-05       NaN -1.454366  0.045759 -0.187184

# %%
df.drop(['Noon', 'Morning'], axis='columns')
# Out:
#              Evening  Midnight
# 1999-12-30       NaN       NaN
# 1999-12-31       NaN -0.151357
# 2000-01-01  0.144044       NaN
# 2000-01-02  0.443863  0.333674
# 2000-01-03  0.313068 -0.854096
# 2000-01-04       NaN -0.742165
# 2000-01-05  0.045759 -0.187184

# %%
df
# Out:
#              Morning      Noon   Evening  Midnight
# 1999-12-30       NaN  0.400157       NaN       NaN
# 1999-12-31       NaN -0.977278       NaN -0.151357
# 2000-01-01 -0.103219  0.410599  0.144044       NaN
# 2000-01-02       NaN  0.121675  0.443863  0.333674
# 2000-01-03       NaN -0.205158  0.313068 -0.854096
# 2000-01-04 -2.552990       NaN       NaN -0.742165
# 2000-01-05       NaN -1.454366  0.045759 -0.187184

# %%
df.at['1999-12-30', 'Noon'] = np.nan
df.at['2000-01-01', 'Midnight'] = df.at['2000-01-03', 'Evening']

df
# Out:
#              Morning      Noon   Evening  Midnight
# 1999-12-30       NaN       NaN       NaN       NaN
# 1999-12-31       NaN -0.977278       NaN -0.151357
# 2000-01-01 -0.103219  0.410599  0.144044  0.313068
# 2000-01-02       NaN  0.121675  0.443863  0.333674
# 2000-01-03       NaN -0.205158  0.313068 -0.854096
# 2000-01-04 -2.552990       NaN       NaN -0.742165
# 2000-01-05       NaN -1.454366  0.045759 -0.187184

# %%
df.dropna(how='any', axis='columns')
# Out:
# Empty DataFrame
# Columns: []
# Index: [1999-12-30 00:00:00, 1999-12-31 00:00:00, 2000-01-01 00:00:00, 2000-01-02 00:00:00, 2000-01-03 00:00:00, 2000-01-04 00:00:00, 2000-01-05 00:00:00]

# %% [markdown]
# ## Sortowanie
#
# - Sortowanie wierszy
#
#     - Sortowanie wierszy
#     - Sortowanie kolumn
#
# - Sortowanie wartości
#
#     - W kolumnach
#     - W wierszach
#
# - Sortowanie rosnąco i malejąco

# %%
df.loc['2000-01-01']
# Out:
# Morning    -0.103219
# Noon        0.410599
# Evening     0.144044
# Midnight    0.313068
# Name: 2000-01-01 00:00:00, dtype: float64

# %%
df.loc['2000-01-01'].sort_index(ascending=False)
# Out:
# Noon        0.410599
# Morning    -0.103219
# Midnight    0.313068
# Evening     0.144044
# Name: 2000-01-01 00:00:00, dtype: float64

# %%
df.sort_index(ascending=False, axis='rows')
# Out:
#              Morning      Noon   Evening  Midnight
# 2000-01-05       NaN -1.454366  0.045759 -0.187184
# 2000-01-04 -2.552990       NaN       NaN -0.742165
# 2000-01-03       NaN -0.205158  0.313068 -0.854096
# 2000-01-02       NaN  0.121675  0.443863  0.333674
# 2000-01-01 -0.103219  0.410599  0.144044  0.313068
# 1999-12-31       NaN -0.977278       NaN -0.151357
# 1999-12-30       NaN       NaN       NaN       NaN

# %%
df.sort_values(by=['Morning', 'Evening'], axis='rows', ascending=False)
# Out:
#              Morning      Noon   Evening  Midnight
# 2000-01-01 -0.103219  0.410599  0.144044  0.313068
# 2000-01-04 -2.552990       NaN       NaN -0.742165
# 2000-01-02       NaN  0.121675  0.443863  0.333674
# 2000-01-03       NaN -0.205158  0.313068 -0.854096
# 2000-01-05       NaN -1.454366  0.045759 -0.187184
# 1999-12-30       NaN       NaN       NaN       NaN
# 1999-12-31       NaN -0.977278       NaN -0.151357

# %%
df.sort_values(by=['2000-01-03', '2000-01-01'], axis='columns', ascending=True)
# Out:
#             Midnight      Noon   Evening   Morning
# 1999-12-30       NaN       NaN       NaN       NaN
# 1999-12-31 -0.151357 -0.977278       NaN       NaN
# 2000-01-01  0.313068  0.410599  0.144044 -0.103219
# 2000-01-02  0.333674  0.121675  0.443863       NaN
# 2000-01-03 -0.854096 -0.205158  0.313068       NaN
# 2000-01-04 -0.742165       NaN       NaN -2.552990
# 2000-01-05 -0.187184 -1.454366  0.045759       NaN

# %% [markdown]
# ## Modyfikacja struktury
#
# - Dodawanie kolumn
# - Dodawanie wierszy
# - Usuwanie kolumn
# - Usuwanie wierszy
# - Transpozycja

# %%
df['NEW'] = np.random.randn(len(df))

# %%
df['NEW2'] = ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
df['NEW3'] = list('abcdefg')

# %%
import string

df['NEW4'] = list(string.ascii_uppercase[:7])

# %%
df['Morning'] = np.arange(7)

# %%
df
# Out:
#             Morning      Noon   Evening  Midnight       NEW NEW2 NEW3 NEW4
# 1999-12-30        0       NaN       NaN       NaN  1.532779    a    a    A
# 1999-12-31        1 -0.977278       NaN -0.151357  1.469359    b    b    B
# 2000-01-01        2  0.410599  0.144044  0.313068  0.154947    c    c    C
# 2000-01-02        3  0.121675  0.443863  0.333674  0.378163    d    d    D
# 2000-01-03        4 -0.205158  0.313068 -0.854096 -0.887786    e    e    E
# 2000-01-04        5       NaN       NaN -0.742165 -1.980796    f    f    F
# 2000-01-05        6 -1.454366  0.045759 -0.187184 -0.347912    g    g    G

# %%
df.drop('NEW4', axis='columns')
# Out:
#             Morning      Noon   Evening  Midnight       NEW NEW2 NEW3
# 1999-12-30        0       NaN       NaN       NaN  1.532779    a    a
# 1999-12-31        1 -0.977278       NaN -0.151357  1.469359    b    b
# 2000-01-01        2  0.410599  0.144044  0.313068  0.154947    c    c
# 2000-01-02        3  0.121675  0.443863  0.333674  0.378163    d    d
# 2000-01-03        4 -0.205158  0.313068 -0.854096 -0.887786    e    e
# 2000-01-04        5       NaN       NaN -0.742165 -1.980796    f    f
# 2000-01-05        6 -1.454366  0.045759 -0.187184 -0.347912    g    g

# %%
df.drop(columns=['NEW4'], inplace=True)

# %%
df.transpose()
# Out:
#          1999-12-30 1999-12-31 2000-01-01 2000-01-02 2000-01-03 2000-01-04  \
# Morning           0          1          2          3          4          5
# Noon            NaN  -0.977278   0.410599   0.121675  -0.205158        NaN
# Evening         NaN        NaN   0.144044   0.443863   0.313068        NaN
# Midnight        NaN  -0.151357   0.313068   0.333674  -0.854096  -0.742165
# NEW         1.53278    1.46936   0.154947   0.378163  -0.887786    -1.9808
# NEW2              a          b          c          d          e          f
# NEW3              a          b          c          d          e          f
#
#          2000-01-05
# Morning           6
# Noon       -1.45437
# Evening   0.0457585
# Midnight  -0.187184
# NEW       -0.347912
# NEW2              g
# NEW3              g

# %%
df.T
# Out:
#          1999-12-30 1999-12-31 2000-01-01 2000-01-02 2000-01-03 2000-01-04  \
# Morning           0          1          2          3          4          5
# Noon            NaN  -0.977278   0.410599   0.121675  -0.205158        NaN
# Evening         NaN        NaN   0.144044   0.443863   0.313068        NaN
# Midnight        NaN  -0.151357   0.313068   0.333674  -0.854096  -0.742165
# NEW         1.53278    1.46936   0.154947   0.378163  -0.887786    -1.9808
# NEW2              a          b          c          d          e          f
# NEW3              a          b          c          d          e          f
#
#          2000-01-05
# Morning           6
# Noon       -1.45437
# Evening   0.0457585
# Midnight  -0.187184
# NEW       -0.347912
# NEW2              g
# NEW3              g

# %%
df
# Out:
#             Morning      Noon   Evening  Midnight       NEW NEW2 NEW3
# 1999-12-30        0       NaN       NaN       NaN  1.532779    a    a
# 1999-12-31        1 -0.977278       NaN -0.151357  1.469359    b    b
# 2000-01-01        2  0.410599  0.144044  0.313068  0.154947    c    c
# 2000-01-02        3  0.121675  0.443863  0.333674  0.378163    d    d
# 2000-01-03        4 -0.205158  0.313068 -0.854096 -0.887786    e    e
# 2000-01-04        5       NaN       NaN -0.742165 -1.980796    f    f
# 2000-01-05        6 -1.454366  0.045759 -0.187184 -0.347912    g    g

# %%
df.append({
    'Morning': 99,
}, ignore_index=True)
# Out:
#    Morning      Noon   Evening  Midnight       NEW NEW2 NEW3
# 0      0.0       NaN       NaN       NaN  1.532779    a    a
# 1      1.0 -0.977278       NaN -0.151357  1.469359    b    b
# 2      2.0  0.410599  0.144044  0.313068  0.154947    c    c
# 3      3.0  0.121675  0.443863  0.333674  0.378163    d    d
# 4      4.0 -0.205158  0.313068 -0.854096 -0.887786    e    e
# 5      5.0       NaN       NaN -0.742165 -1.980796    f    f
# 6      6.0 -1.454366  0.045759 -0.187184 -0.347912    g    g
# 7     99.0       NaN       NaN       NaN       NaN  NaN  NaN

# %%
new = pd.DataFrame({
    'Morning': [99, 0] * 2,
    'Midnight': [0, 9, 'a', pd.NA],
    'XXX': [7, 1, 3,344]
}, index=pd.date_range('2000-02-01', periods=4, freq='D'))

new
# Out:
#             Morning Midnight  XXX
# 2000-02-01       99        0    7
# 2000-02-02        0        9    1
# 2000-02-03       99        a    3
# 2000-02-04        0     <NA>  344

# %%
df
# Out:
#             Morning      Noon   Evening  Midnight       NEW NEW2 NEW3
# 1999-12-30        0       NaN       NaN       NaN  1.532779    a    a
# 1999-12-31        1 -0.977278       NaN -0.151357  1.469359    b    b
# 2000-01-01        2  0.410599  0.144044  0.313068  0.154947    c    c
# 2000-01-02        3  0.121675  0.443863  0.333674  0.378163    d    d
# 2000-01-03        4 -0.205158  0.313068 -0.854096 -0.887786    e    e
# 2000-01-04        5       NaN       NaN -0.742165 -1.980796    f    f
# 2000-01-05        6 -1.454366  0.045759 -0.187184 -0.347912    g    g

# %%
new
# Out:
#             Morning
# 2000-02-01       99

# %%
df.append(new)
# Out:
#             Morning      Noon   Evening  Midnight       NEW NEW2 NEW3    XXX
# 1999-12-30        0       NaN       NaN       NaN  1.532779    a    a    NaN
# 1999-12-31        1 -0.977278       NaN -0.151357  1.469359    b    b    NaN
# 2000-01-01        2  0.410599  0.144044  0.313068  0.154947    c    c    NaN
# 2000-01-02        3  0.121675  0.443863  0.333674  0.378163    d    d    NaN
# 2000-01-03        4 -0.205158  0.313068 -0.854096 -0.887786    e    e    NaN
# 2000-01-04        5       NaN       NaN -0.742165 -1.980796    f    f    NaN
# 2000-01-05        6 -1.454366  0.045759 -0.187184 -0.347912    g    g    NaN
# 2000-02-01       99       NaN       NaN         0       NaN  NaN  NaN    7.0
# 2000-02-02        0       NaN       NaN         9       NaN  NaN  NaN    1.0
# 2000-02-03       99       NaN       NaN         a       NaN  NaN  NaN    3.0
# 2000-02-04        0       NaN       NaN      <NA>       NaN  NaN  NaN  344.0

# %% [markdown]
# ## Aplikowanie funkcji
#
# - map
# - apply
# - applymap
# - Różnice
# - Kiedy które
#
#
# <img src="img/pandas-df-mapping.png" width="800" />

# %%
df['Midnight'] = df['Midnight'].round()

# %%
df.apply(str)
# Out:
# Morning     1999-12-30    0\n1999-12-31    1\n2000-01-01  ...
# Noon        1999-12-30         NaN\n1999-12-31   -0.977278...
# Evening     1999-12-30         NaN\n1999-12-31         NaN...
# Midnight    1999-12-30    NaN\n1999-12-31   -0.0\n2000-01-...
# NEW         1999-12-30    1.532779\n1999-12-31    1.469359...
# NEW2        1999-12-30    a\n1999-12-31    b\n2000-01-01  ...
# NEW3        1999-12-30    a\n1999-12-31    b\n2000-01-01  ...
# dtype: object

# %%
df['Noon'].map(str)
# Out:
# 1999-12-30                     nan
# 1999-12-31      -0.977277879876411
# 2000-01-01     0.41059850193837233
# 2000-01-02     0.12167501649282841
# 2000-01-03    -0.20515826376580087
# 2000-01-04                     nan
# 2000-01-05     -1.4543656745987648
# Freq: D, Name: Noon, dtype: object

# %%
# https://python.astrotech.io/numerical-analysis/pandas/df-mapping.html#summary

# %%
df['Morning'] = df['Morning'] + 1

# %%
df
# Out:
#             Morning      Noon   Evening  Midnight       NEW NEW2 NEW3
# 1999-12-30        1       NaN       NaN       NaN  1.532779    a    a
# 1999-12-31        2 -0.977278       NaN      -0.0  1.469359    b    b
# 2000-01-01        3  0.410599  0.144044       0.0  0.154947    c    c
# 2000-01-02        4  0.121675  0.443863       0.0  0.378163    d    d
# 2000-01-03        5 -0.205158  0.313068      -1.0 -0.887786    e    e
# 2000-01-04        6       NaN       NaN      -1.0 -1.980796    f    f
# 2000-01-05        7 -1.454366  0.045759      -0.0 -0.347912    g    g

# %%
df['Morning'] = df['Morning'].map(lambda x: x+1)
# Out:
# 1999-12-30    2
# 1999-12-31    3
# 2000-01-01    4
# 2000-01-02    5
# 2000-01-03    6
# 2000-01-04    7
# 2000-01-05    8
# Freq: D, Name: Morning, dtype: int64

# %%
MONTH = {
    "01": "January",
    "02": "February",
    "03": "March",
    "04": "April",
    "05": "May",
    "06": "June",
    "07": "July",
    "08": "August",
    "09": "September",
    "10": "October",
    "11": "November",
    "12": "December",
}

# %%
df['Morning'] = df['Morning'].map(str)

# %%
df['Morning'].str[:4]
# Out:
# 1999-12-30    1
# 1999-12-31    2
# 2000-01-01    3
# 2000-01-02    4
# 2000-01-03    5
# 2000-01-04    6
# 2000-01-05    7
# Freq: D, Name: Morning, dtype: object

# %%
df
# Out:
#            Morning      Noon   Evening  Midnight       NEW NEW2 NEW3
# 1999-12-30       1       NaN       NaN       NaN  1.532779    a    a
# 1999-12-31       2 -0.977278       NaN      -0.0  1.469359    b    b
# 2000-01-01       3  0.410599  0.144044       0.0  0.154947    c    c
# 2000-01-02       4  0.121675  0.443863       0.0  0.378163    d    d
# 2000-01-03       5 -0.205158  0.313068      -1.0 -0.887786    e    e
# 2000-01-04       6       NaN       NaN      -1.0 -1.980796    f    f
# 2000-01-05       7 -1.454366  0.045759      -0.0 -0.347912    g    g

# %%
df['NEW'] = df['NEW'].map(str)

# %%
df['NEW'].str[0:5]
# Out:
# 1999-12-30    1.532
# 1999-12-31    1.469
# 2000-01-01    0.154
# 2000-01-02    0.378
# 2000-01-03    -0.88
# 2000-01-04    -1.98
# 2000-01-05    -0.34
# Freq: D, Name: NEW, dtype: object

# %%
df['NEW'].str.split('.', expand=True)
# Out:
#              0                  1
# 1999-12-30   1   5327792143584575
# 1999-12-31   1    469358769900285
# 2000-01-01   0   1549474256969163
# 2000-01-02   0  37816251960217356
# 2000-01-03  -0   8877857476301128
# 2000-01-04  -1    980796468223927
# 2000-01-05  -0   3479121493261526

# %%
pd.Series.str?
