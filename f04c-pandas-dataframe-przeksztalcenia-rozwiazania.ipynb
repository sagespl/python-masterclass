# %% [markdown]
# # Pandas - DataFrame - przekształcenia - zadania

# %%
import pandas as pd
import numpy as np
from doctest import testmod

# %% [markdown]
# ## DataFrame NaN
#
# 1. Użyj danych z sekcji "Input" (patrz poniżej)
# 1. Wczytaj dane z ``DATA`` jako ``iris: pd.DataFrame``
# 1. Pomiń pierwszą linię z metadanymi
# 1. Zmień nazwy kolumn na:
#
#     * Sepal length
#     * Sepal width
#     * Petal length
#     * Petal width
#     * Species
#
# 1. Podmień wartości w kolumnie species
#
#     * 0 -> 'setosa',
#     * 1 -> 'versicolor',
#     * 2 -> 'virginica'
#
# 1. Wybierz wartości w kolumnie 'Petal length' mniejsze od 4
# 1. Wybrane wartości ustaw na ``NaN``
# 1. Interpoluj liniowo wszystkie wartości ``NaN``
# 1. Usuń wiersze z pozostałymi wartościami ``NaN``
# 1. Wypisz dwa pierwsze wiersze
# 1. Wypisz liczbę wierszy

# %%
DATA = 'https://raw.githubusercontent.com/AstroMatt/book-python/master/_data/csv/iris-dirty.csv'

COLUMNS = [
    'Sepal length',
    'Sepal width',
    'Petal length',
    'Petal width',
    'Species']

SPECIES = {
    0: 'setosa',
    1: 'versicolor',
    2: 'virginica'}


iris = pd.read_csv(DATA, names=COLUMNS, skiprows=1)

# %%
iris['Species'].replace(SPECIES, inplace=True)
iris[iris['Petal length'] < 4] = np.nan

# %%
iris = iris.interpolate()
iris = iris.dropna()

# %%
iris.head(2)
# Out:
#    Sepal length  Sepal width  Petal length  Petal width     Species
# 1           5.9          3.0           5.1          1.8   virginica
# 2           6.0          3.4           4.5          1.6  versicolor

# %%
len(iris)
# Out:
# 89

# %% [markdown]
# ## DataFrame Mapping Split
#
# 1. Użyj danych z sekcji "Input" (patrz poniżej)
# 1. Wczytaj dane z ``DATA`` jako ``phones: pd.DataFrame``
# 1. Sparsuj dane w kolumnie ``date`` jako obiekty ``datetime``
# 1. Podziel kolumnę z ``date`` na dwie osobne: datę i czas
#
# Podpowiedź:
# * ``help(phones['date'].dt)``

# %%
DATA = 'https://raw.githubusercontent.com/AstroMatt/book-python/master/_data/csv/phones-pl.csv'

phones = pd.read_csv(DATA)
phones[['date', 'time']] = phones['datetime'].str.split(expand=True)
phones = pd.to_datetime(phones['date'])
phones
# Out:
# 0     1999-10-15
# 1     1999-10-15
# 2     1999-10-15
# 3     1999-10-15
# 4     1999-10-15
#          ...
# 825   2000-03-13
# 826   2000-03-13
# 827   2000-03-13
# 828   2000-03-14
# 829   2000-03-14
# Name: date, Length: 830, dtype: datetime64[ns]

# %%
DATA = 'https://raw.githubusercontent.com/AstroMatt/book-python/master/_data/csv/phones-pl.csv'

phones = pd.read_csv(DATA, parse_dates=['datetime'])
phones['date'] = phones['datetime'].dt.date
phones['time'] = phones['datetime'].dt.time

# %%
# Out:
# datetime.date(1999, 10, 15)

# %% [markdown]
# ## DataFrame Mapping Translate
#
# 1. Użyj danych z sekcji "Input" (patrz poniżej)
# 1. Wczytaj dane z ``DATA`` jako ``martian: pd.DataFrame``
# 1. Ustaw nagłówek i index na dane zaczytane z pliku
# 1. Przekonwertuj polskie nazwy miesięcy na angielskie
# 1. Sparsuj daty do obiektów ``datetime``
#
# Podpowiedź:
# * ``df['column'].replace(regex=True)``
# * ``pd.Timestamp``

# %%
DATA = 'https://raw.githubusercontent.com/AstroMatt/book-python/master/_data/csv/martian-pl.csv'

MONTHS_PLEN = {'styczeń': 'January',
               'luty': 'February',
               'marzec': 'March',
               'kwiecień': 'April',
               'maj': 'May',
               'czerwiec': 'June',
               'lipiec': 'July',
               'sierpień': 'August',
               'wrzesień': 'September',
               'październik': 'October',
               'listopad': 'November',
               'grudzień': 'December'}

# %%
martian = pd.read_csv(DATA)

# %%
martian['Mission Date'] = (
    martian['Mission Date']
    .replace(MONTHS_PLEN, regex=True)
    .map(pd.Timestamp))

# %%
martian.set_index('id')
# Out:
#    First Name   Last Name Mission Date
# id
# 1         Jan  Twardowski   1988-01-05
# 2        Mark      Watney   1969-07-21
# 3        Ivan   Ivanovich   1961-04-12
# 4     Melissa       Lewis   1970-01-01
# 5        Alex       Vogel   1968-12-25

# %% [markdown]
# ## DataFrame Mapping Month
#
# 1. Użyj danych z sekcji "Input" (patrz poniżej)
# 1. Wczytaj dane z ``DATA`` jako ``phones: pd.DataFrame``
# 1. Dodaj kolumnę ``year`` i ``month_name`` poprzez sparsowanie kolumny ``month``
# 1. Nazwa miesiąca musi być ciągiem znaków, a nie liczbą (i.e. 'January', 'May')
#
# Przykład:
# 1. jeżeli ``period`` column is "2015-01"
# 1. ``year``: 2015
# 1. ``month``: January
#
# Podpowiedź:
# * ``Series.str.split(expand=True)``
# * ``df[ ['A', 'B'] ] = ...``

# %%
DATA = 'https://raw.githubusercontent.com/AstroMatt/book-python/master/_data/csv/phones-en.csv'

MONTHS_EN = ['January', 'February', 'March', 'April',
             'May', 'June', 'July', 'August', 'September',
             'October', 'November', 'December']

MONTHS = dict(enumerate(MONTHS_EN, start=1))

# %%
phones = pd.read_csv(DATA, parse_dates=['date'])
phones[['year', 'month_name']] = phones['month'].str.split('-', expand=True)
phones
# Out:
#      index                date  duration  item    month   network  \
# 0        0 2014-10-15 06:58:00    34.429  data  2014-11      data
# 1        1 2014-10-15 06:58:00    13.000  call  2014-11  Vodafone
# 2        2 2014-10-15 14:46:00    23.000  call  2014-11    Meteor
# 3        3 2014-10-15 14:48:00     4.000  call  2014-11     Tesco
# 4        4 2014-10-15 17:27:00     4.000  call  2014-11     Tesco
# ..     ...                 ...       ...   ...      ...       ...
# 825    825 2015-03-13 00:38:00     1.000   sms  2015-03     world
# 826    826 2015-03-13 00:39:00     1.000   sms  2015-03  Vodafone
# 827    827 2015-03-13 06:58:00    34.429  data  2015-03      data
# 828    828 2015-03-14 00:13:00     1.000   sms  2015-03     world
# 829    829 2015-03-14 00:16:00     1.000   sms  2015-03     world
#
#     network_type  year month_name
# 0           data  2014         11
# 1         mobile  2014         11
# 2         mobile  2014         11
# 3         mobile  2014         11
# 4         mobile  2014         11
# ..           ...   ...        ...
# 825        world  2015         03
# 826       mobile  2015         03
# 827         data  2015         03
# 828        world  2015         03
# 829        world  2015         03
#
# [830 rows x 9 columns]

# %%
phones['month_name'] = phones['month_name'].map(int).replace(MONTHS)

# %%
phones
# Out:
#      index                date  duration  item    month   network  \
# 0        0 2014-10-15 06:58:00    34.429  data  2014-11      data
# 1        1 2014-10-15 06:58:00    13.000  call  2014-11  Vodafone
# 2        2 2014-10-15 14:46:00    23.000  call  2014-11    Meteor
# 3        3 2014-10-15 14:48:00     4.000  call  2014-11     Tesco
# 4        4 2014-10-15 17:27:00     4.000  call  2014-11     Tesco
# ..     ...                 ...       ...   ...      ...       ...
# 825    825 2015-03-13 00:38:00     1.000   sms  2015-03     world
# 826    826 2015-03-13 00:39:00     1.000   sms  2015-03  Vodafone
# 827    827 2015-03-13 06:58:00    34.429  data  2015-03      data
# 828    828 2015-03-14 00:13:00     1.000   sms  2015-03     world
# 829    829 2015-03-14 00:16:00     1.000   sms  2015-03     world
#
#     network_type  year month_name
# 0           data  2014   November
# 1         mobile  2014   November
# 2         mobile  2014   November
# 3         mobile  2014   November
# 4         mobile  2014   November
# ..           ...   ...        ...
# 825        world  2015      March
# 826       mobile  2015      March
# 827         data  2015      March
# 828        world  2015      March
# 829        world  2015      March
#
# [830 rows x 9 columns]

# %%
MONTHS_EN = ['January', 'February', 'March', 'April',
             'May', 'June', 'July', 'August', 'September',
             'October', 'November', 'December']

MONTHS = {str(i):month for i, month in enumerate(MONTHS_EN, start=1)}


MONTHS
# Out:
# {'1': 'January',
#  '2': 'February',
#  '3': 'March',
#  '4': 'April',
#  '5': 'May',
#  '6': 'June',
#  '7': 'July',
#  '8': 'August',
#  '9': 'September',
#  '10': 'October',
#  '11': 'November',
#  '12': 'December'}

# %% [markdown]
# ## DataFrame Mapping Substitute
#
# 1. Użyj danych z sekcji "Input" (patrz poniżej)
# 1. Wczytaj dane z ``DATA`` jako ``trl: pd.DataFrame``
# 1. Wybierz arkusz ``Polish``
# 1. Ustaw nagłówek i index na dane zaczytane z pliku
# 1. Zwróć uwagę na encoding
# 1. Podmień polskie znaki diakrytyczne na litery z alfabetu angielskiego
# 1. Porównaj ``df.replace(regex=True)`` z ``df.applymap()``

# %%
DATA = 'https://raw.githubusercontent.com/AstroMatt/book-python/master/_data/xlsx/astro-trl.xlsx'

LETTERS_PLEN = {'ą': 'a', 'ć': 'c', 'ę': 'e',
                'ł': 'l', 'ń': 'n', 'ó': 'o',
                'ś': 's', 'ż': 'z', 'ź': 'z'}

# %%
trl = pd.read_excel(DATA, sheet_name='Polish', index_col='TRL', header=1)

# %%
def pl2acscii(text):
    """
    >>> pl2acscii('ą')
    'a'
    >>> pl2acscii('ś')
    's'
    >>> pl2acscii('zażółć gęślą jaźń')
    'zazolc gesla jazn'
    """
    return ''.join(LETTERS_PLEN.get(x,x) for x in text)
        

testmod()
# Out:
# TestResults(failed=0, attempted=6)

# %%
trl = trl.applymap(pl2acscii)
trl.columns = trl.columns.map(pl2acscii)

trl
# Out:
#                                              Definicja  \
# TRL
# 1    Zaobserwowanie i opisanie podstawowych zasad d...
# 2    Sformulowanie koncepcji technologicznej lub pr...
# 3    Przeprowadzanie eksperymentalnie i analityczni...
# 4    Przeprowadzenie weryfikacji komponentow techno...
# 5    Przeprowadzenie weryfikacji komponentow techno...
# 6    Dokonanie demonstracji technologii w srodowisk...
# 7    Dokonanie demonstracji prototypu systemu w oto...
# 8    Zakonczenie badan i demonstracja ostatecznej f...
# 9    Weryfikacja technologii w srodowisku operacyjn...
#
#                                                 Sprzet  \
# TRL
# 1    Zebrano wiedze naukowa dotyczaca podstawowych ...
# 2    Stworzono innowacyjne rozwiazanie, zidentyfiko...
# 3    Badania analityczne pozwalaja na umieszczenie ...
# 4    Stworzono niskiej wiernosci system lub jego ko...
# 5    Stworzono sredniej wiernosci system lub jego k...
# 6    Stworzono wysokiej wiernosci system lub jego k...
# 7    Stworzono wysokiej wiernosci system lub jego k...
# 8    Produkt koncowy w swojej ostatecznej konfigura...
# 9    Produkt koncowy jest z powodzeniem obslugiwany...
#
#                                         Oprogramowanie  \
# TRL
# 1    Zebrano wiedze naukowa dotyczaca podstawowych ...
# 2    Zidentyfikowano praktyczne zastosowanie, ale m...
# 3    Opracowanie ograniczonej funkcjonalnosci do wa...
# 4    Kluczowe, funkcjonalne komponenty oprogramowan...
# 5    Zaimplementowane kompleksowe elementy oprogram...
# 6    Stworzona prototypowa implementacja oprogramow...
# 7    Prototypowe oprogramowanie posiada wszystkie k...
# 8    Cale oprogramowanie zostalo gruntownie sprawdz...
# 9    Cale oprogramowanie zostalo gruntownie sprawdz...
#
#                                     Kryteria wyjsciowe
# TRL
# 1    Zweryfikowane publikacja badania lezacych u po...
# 2    Udokumentowany opis aplikacji / koncepcji, kto...
# 3    Udokumentowane wyniki analityczne / eksperymen...
# 4    Udokumentowane wyniki testow potwierdzajace zg...
# 5    Udokumentowane wyniki testow potwierdzajace zg...
# 6    Udokumentowane wyniki testow potwierdzajace zg...
# 7    Udokumentowane wyniki testow potwierdzajace zg...
# 8    Udokumentowane wyniki testow weryfikujacych pr...
# 9              Udokumentowane wyniki operacyjne misji.

# %%
# %pip install xlrd
# Out:
# Collecting xlrd
#   Using cached xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
trl = pd.read_excel(DATA, sheet_name='Polish', index_col='TRL', header=1)
trl.replace(LETTERS_PLEN, regex=True, inplace=True)
trl.columns = trl.columns.map(pl2acscii)

trl

# %%
# Out:
#                                              Definicja  \
# TRL
# 1    Zaobserwowanie i opisanie podstawowych zasad d...
# 2    Sformulowanie koncepcji technologicznej lub pr...
# 3    Przeprowadzanie eksperymentalnie i analityczni...
# 4    Przeprowadzenie weryfikacji komponentow techno...
# 5    Przeprowadzenie weryfikacji komponentow techno...
# 6    Dokonanie demonstracji technologii w srodowisk...
# 7    Dokonanie demonstracji prototypu systemu w oto...
# 8    Zakonczenie badan i demonstracja ostatecznej f...
# 9    Weryfikacja technologii w srodowisku operacyjn...
#
#                                                 Sprzet  \
# TRL
# 1    Zebrano wiedze naukowa dotyczaca podstawowych ...
# 2    Stworzono innowacyjne rozwiazanie, zidentyfiko...
# 3    Badania analityczne pozwalaja na umieszczenie ...
# 4    Stworzono niskiej wiernosci system lub jego ko...
# 5    Stworzono sredniej wiernosci system lub jego k...
# 6    Stworzono wysokiej wiernosci system lub jego k...
# 7    Stworzono wysokiej wiernosci system lub jego k...
# 8    Produkt koncowy w swojej ostatecznej konfigura...
# 9    Produkt koncowy jest z powodzeniem obslugiwany...
#
#                                         Oprogramowanie  \
# TRL
# 1    Zebrano wiedze naukowa dotyczaca podstawowych ...
# 2    Zidentyfikowano praktyczne zastosowanie, ale m...
# 3    Opracowanie ograniczonej funkcjonalnosci do wa...
# 4    Kluczowe, funkcjonalne komponenty oprogramowan...
# 5    Zaimplementowane kompleksowe elementy oprogram...
# 6    Stworzona prototypowa implementacja oprogramow...
# 7    Prototypowe oprogramowanie posiada wszystkie k...
# 8    Cale oprogramowanie zostalo gruntownie sprawdz...
# 9    Cale oprogramowanie zostalo gruntownie sprawdz...
#
#                                     Kryteria wyjsciowe
# TRL
# 1    Zweryfikowane publikacja badania lezacych u po...
# 2    Udokumentowany opis aplikacji / koncepcji, kto...
# 3    Udokumentowane wyniki analityczne / eksperymen...
# 4    Udokumentowane wyniki testow potwierdzajace zg...
# 5    Udokumentowane wyniki testow potwierdzajace zg...
# 6    Udokumentowane wyniki testow potwierdzajace zg...
# 7    Udokumentowane wyniki testow potwierdzajace zg...
# 8    Udokumentowane wyniki testow weryfikujacych pr...
# 9              Udokumentowane wyniki operacyjne misji.
